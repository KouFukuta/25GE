# %%
# -*- coding: sjis -*-

#------------------------------------------
#  ���f���� tokenizer �̐ݒ�
#------------------------------------------

import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

# モデルの読み込み
# model_name = "cyberagent/open-calm-small"
model_name = "./tunedModels/kariModels/kari1-2/checkpoint-2100"

model = AutoModelForCausalLM.from_pretrained(
    model_name, 
    torch_dtype=torch.bfloat16,
    )

tokenizer = AutoTokenizer.from_pretrained("cyberagent/open-calm-small")

#----------------------------------
#  �f�[�^�̃_�E�����[�h
#----------------------------------

import datasets
query = datasets.load_dataset("json", data_files="./trainData/question_fukabori2.json")

#----------------------------------
#  �e���v���[�g
#----------------------------------

# 初手の質問生成用テンプレート
template = {
    "w_input": (
        "以下はタスクを記述した指示と入力です。入力はタスクで参照されている文章です。指示を適切に満たす応答を書きなさい。\n\n"
        "### 指示:\n{instruction}\n\n"
        "### 入力:\n{input}\n\n"
        "### 応答:\n{output}"
    ),
    "wo_input": (
        "以下はタスクを記述した指示と入力です。入力はタスクで参照されている文章です。指示を適切に満たす応答を書きなさい。\n\n"
        "### 指示:\n{instruction}\n\n"
        "### 応答:\n{output}"
    )
}

# 回答、深掘り用テンプレート
# template = {
#     "w_input": (
#         "以下はユーザーとの会話です。内容を深堀りし、ユーザーに質問をしてください。\n\n"
#         "### 指示:\n{instruction}\n\n"
#         "### 入力:\n{input}\n\n"
#         "### 応答:\n{output}"
#     ),
    
#     "wo_input": (
#         "以下はユーザーとの会話です。内容を深堀りし、ユーザーに質問をしてください。\n\n"
#         "### 指示:\n{instruction}\n\n"
#         "### 応答:\n{output}"
#     )
# }

#------------------------------------------
#  �f�[�^�i�v�����v�g�j�̃��X�g�̍쐬
#------------------------------------------

datalist = []
for d in query['train']:
    if 'instruction' not in d or 'output' not in d:
        continue
    input_text = d.get('input', None)
    if input_text in [None, '']:  # input がない、または空文字
        ptext = template['wo_input'].format_map(d)
    else:
        d = {**d, 'input': input_text}  # 念のため補完しておく
        ptext = template['w_input'].format_map(d)
    if len(ptext) < 1500:
        datalist.append(ptext)

        
#------------------------------------------
#  train_dataset �̍\�z
#------------------------------------------

from torch.utils.data import Dataset

class MyDataset(Dataset):
    def __init__(self, datalist, tokenizer):
        self.tokenizer = tokenizer
        self.features = []
        for ptext in datalist:
            input_ids = self.tokenizer.encode(ptext)
            input_ids = input_ids + [ self.tokenizer.eos_token_id ]
            input_ids = torch.LongTensor(input_ids)
            self.features.append({'input_ids': input_ids})
    def __len__(self):
        return len(self.features)
    def __getitem__(self, idx):
        return self.features[idx]

train_dataset = MyDataset(datalist, tokenizer)

#------------------------------------------
#  Trainer �̐ݒ�Ɗw�K�̎��s
#------------------------------------------

from transformers import Trainer, TrainingArguments
from transformers import DataCollatorForLanguageModeling

collator = DataCollatorForLanguageModeling(tokenizer, mlm=False)

training_args = TrainingArguments(
    output_dir='./tunedModels/kariModels/kari1-3',
    num_train_epochs=5,    
    save_steps=2000,
    logging_steps=100,
    per_device_train_batch_size=1
)

trainer = Trainer(
    model=model,
    data_collator=collator,
    args=training_args,
    train_dataset=train_dataset
)

trainer.train()
# Out:
# Generating train split: 216 examples [00:00, 35526.83 examples/s]
#     <div>
#
#       <progress value='1080' max='1080' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [1080/1080 02:56, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>0.715300</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.725100</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.701800</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.618800</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.633400</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.609800</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.610800</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.645900</td>
#     </tr>
#     <tr>
# ...

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

model = AutoModelForCausalLM.from_pretrained(
    "./tunedModels/kariModels/kari1-3/checkpoint-1080"
    # "./tunedModels/prototype_fukaboriII/checkpoint-500",
    # "./tunedModels/prototype_fukabori/checkpoint-150"
    # "./tunedModels/prototype/checkpoint-3145"
    # "cyberagent/open-calm-small"
)
tokenizer = AutoTokenizer.from_pretrained(
    "cyberagent/open-calm-small"
)

template = {
    "w_input": (
        "以下はユーザーからの質問です。入力はタスクで参照されている文章です。質問を適切に満たす応答を書きなさい。\n\n"
        "### 指示:\n{instruction}\n\n"
        "### 入力:\n{input}\n\n"
        "### 応答:\n{output}"
    ),
    
    "wo_input": (
        "以下はユーザーからの質問です。入力はタスクで参照されている文章です。質問を適切に満たす応答を書きなさい。\n\n"
        "### 指示:\n{instruction}\n\n"
        "### 応答:\n{output}"
    )
}

d = {}
d['instruction'] = ""
d['output'] = ""

ptext = template['wo_input'].format_map(d)

input = tokenizer.encode(
    ptext,
    return_tensors="pt"
)
start_pos = len(input[0])
with torch.no_grad():
    tokens = model.generate(
        input,
        max_new_tokens=128,
        do_sample=True,
        pad_token_id=tokenizer.eos_token_id,
        temperature=0.7,
        top_p=0.9,
)

output = tokenizer.decode(tokens[0][start_pos:], skip_special_tokens=True)

print("user: " + d['instruction'])
print("output: " + output)
# Out:
# user: 日常についての質問を出して
# output: 普段のどんなことを大切にしていますか?
#
# ### 質問:
# 自分の経験について
#
# ### 質問:

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

model = AutoModelForCausalLM.from_pretrained(
    # "cyberagent/open-calm-small"
    # "tunedModels/prototypeV3/checkpoint-125"
    "./tunedModels/prototype_fukabori/checkpoint-150"
)
tokenizer = AutoTokenizer.from_pretrained(
    "cyberagent/open-calm-small"
)

template = {
    "w_input": (
        "以下はタスクを記述した指示と入力です。入力はタスクで参照されている文章です。指示を適切に満たす応答を書きなさい。\n\n"
        "### 指示:\n{instruction}\n\n"
        "### 入力:\n{input}\n\n"
        "### 応答:\n"
    ),
    "wo_input": (
        "以下はタスクを記述した指示と入力です。入力はタスクで参照されている文章です。指示を適切に満たす応答を書きなさい。\n\n"
        "### 指示:\n{instruction}\n\n"
        "### 応答:\n"
    )
}

d = {}
d['instruction'] = "今日は暑いです。"
d['output'] = ""

ptext = template['wo_input'].format_map(d)

input = tokenizer.encode(
    ptext,
    return_tensors="pt"
)
start_pos = len(input[0])
with torch.no_grad():
    tokens = model.generate(
        input,
        max_new_tokens=128,
        do_sample=True,
        pad_token_id=tokenizer.eos_token_id,
        temperature=0.7,
        top_p=0.9,
)

output = tokenizer.decode(tokens[0][start_pos:], skip_special_tokens=True)

print("user: " + d['instruction'])
print("output: " + output)
# Out:
# user: 今日は暑いです。
# output: 今日、私は暑くて暑くて眠れません。
#
# ### 応答:
# 暑い夏ですが、どうしたらいいですか?

# %%
import torch

print("PyTorch version:", torch.__version__)
print("MPS available:", torch.backends.mps.is_available())
print("MPS built:", torch.backends.mps.is_built())
# Out:
# PyTorch version: 2.6.0
# MPS available: True
# MPS built: True
